# %%
# 책에 대한 class 정의
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

# %%
# Library에 대한 class 정의

class Library:
    def __init__(self, name): #library 안에는 library의 이름과 그 안에 들어있는 책으로 구성.
        self.name = name
        self.books = []

    def add_book(self, book, manager): #책을 추가하는 함수
        self.books.append(book) # 이걸 빈칸으로 뚫을까.
        manager.add_book_to_library(book, self)  # 도서를 도서관에 추가하고 매핑 (이건 줘야함.)

    def show_books(self): # 해당 도서관에 들어있는 책을 보여주기
        for i in range(len(self.books)):
            print(self.books[i].title, self.books[i].author, self.books[i].year)

    def sort_books_title(self): #삽입정렬 사용
        for i in range(1, len(self.books)):
            key = self.books[i]
            j = i - 1
            while j >= 0 and self.books[j].title.lower() > key.title.lower():
                self.books[j + 1] = self.books[j]
                j -= 1
            self.books[j + 1] = key

    def search_book(self, query): #책 이름 혹은 작가 이름으로 검색 / 이 부분 통째로 뚫어버릴거야. #linear search
        found_books = []
        for book in self.books: 
            if query.lower() in book.title.lower() or query.lower() in book.author.lower(): 
                found_books.append(book)
        return found_books

# %%
# Library Manager를 만드는 이유는 Library를 묶어줄 class가 필요하며,
# 이 클래스의 경우 어느 책이 어느 도서관에 있는지를 알려주는 것이다.

class LibraryManager:
    def __init__(self):
        self.libraries = []
        self.book_to_library_map = {}

    def add_library(self, library):
        self.libraries.append(library)

    def select_library(self, library_name):
        for library in self.libraries:
            if library.name == library_name:
                return library
        return None

    def add_book_to_library(self, book, library):
        self.book_to_library_map[book.title] = library

    def find_library_of_book(self, book_title):
        matching_books = {}  # 일치하는 도서 정보를 저장할 딕셔너리
        for title, library in self.book_to_library_map.items():
            if book_title.lower() in title.lower():
                matching_books[title] = library
        return matching_books

# %%
with open("library.txt", "r") as file :
    books = []
    for line in file : 
        book = line.strip('\n').split(', ')
        books.append(book)
books
# Out:
# [['Open-architected transitional model',
#   'Nicole Bailey',
#   '1933',
#   'Main Library'],
#  ['Phased dedicated application',
#   'Kayla Mitchell',
#   '2004',
#   'Engineering Library'],
#  ['Multi-layered optimizing workforce',
#   'David Hudson',
#   '1975',
#   'Main Library'],
#  ['Distributed even-keeled open architecture',
#   'Jacob Harrison',
#   '1915',
#   'Engineering Library'],
#  ['Visionary zero tolerance structure',
#   'Kathleen Sanchez',
#   '1999',
#   'Main Library'],
#  ['Profound client-driven archive',
#   'Jay Greene',
#   '1993',
#   'Engineering Library'],
#  ['Face-to-face 6thgeneration ability',
#   'Elizabeth Weaver',
#   '2016',
#   'Data Science Library'],
#  ['Open-source bifurcated intranet',
#   'Nicole Rosario',
#   '1956',
#   'Engineering Library'],
#  ['Vision-oriented systemic architecture',
#   'Amanda Rose',
#   '1912',
#   'Main Library'],
#  ['Devolved mobile software',
#   'Matthew Montoya',
#   '1975',
#   'Engineering Library'],
#  ['Synergized upward-trending application',
#   'Tammy Keith',
#   '1913',
#   'Data Science Library'],
#  ['Extended interactive alliance',
#   'Cassie Barnes',
#   '2010',
#   'Data Science Library'],
#  ['Future-proofed empowering frame', 'Sean Nixon', '1979', 'Main Library'],
#  ['Persevering composite complexity',
#   'Madison Ramos',
#   '2000',
#   'Engineering Library'],
#  ['Organized multi-state throughput',
#   'Brandon Manning',
#   '1919',
#   'Data Science Library'],
#  ['Virtual 4thgeneration task-force',
#   'John Gilbert',
#   '1932',
#   'Engineering Library'],
#  ['Polarized encompassing orchestration',
#   'Jason Haas',
#   '1963',
#   'Engineering Library'],
#  ['Reduced leadingedge hierarchy',
#   'Amy Johnson',
#   '1957',
#   'Data Science Library'],
#  ['Balanced upward-trending database',
#   'Trevor Bell',
#   '1999',
#   'Engineering Library'],
#  ['Expanded even-keeled paradigm',
#   'Melissa Smith',
#   '1992',
#   'Engineering Library'],
#  ['Object-based incremental projection',
#   'Mike Rodriguez',
#   '1924',
#   'Main Library'],
#  ['Robust attitude-oriented circuit', 'Joshua Jones', '1948', 'Main Library'],
#  ['Open-source client-driven methodology',
#   'Nicole Russell',
#   '1989',
#   'Engineering Library'],
#  ['Assimilated 3rdgeneration throughput',
#   'Laura Martinez',
#   '1920',
#   'Main Library'],
#  ['Intuitive composite neural-net',
#   'Dalton Mercado',
#   '1984',
#   'Engineering Library'],
#  ['Mandatory zero administration customer loyalty',
#   'Kayla Walker',
#   '1919',
#   'Main Library'],
#  ['Networked actuating model', 'Jamie Hansen', '2015', 'Engineering Library'],
#  ['Intuitive intangible customer loyalty',
#   'Jason Wells',
#   '1986',
#   'Data Science Library'],
#  ['Secured responsive open system',
#   'Hector Santos',
#   '1950',
#   'Engineering Library'],
#  ['Cross-platform transitional leverage',
#   'Lisa Hurley',
#   '1933',
#   'Data Science Library'],
#  ['Networked 5thgeneration firmware', 'Pamela White', '1946', 'Main Library'],
#  ['Visionary asynchronous capability',
#   'Nathaniel Gallagher',
#   '1903',
#   'Main Library'],
#  ['Fully-configurable upward-trending installation',
#   'Scott Love',
#   '1939',
#   'Data Science Library'],
#  ['Visionary systemic website', 'Maria Mcmahon', '1916', 'Main Library'],
#  ['Business-focused even-keeled complexity',
#   'Laura Rich',
#   '1971',
#   'Engineering Library'],
#  ['Focused mobile concept', 'Misty Stephenson', '1967', 'Engineering Library'],
#  ['Balanced real-time monitoring',
#   'Joshua Jones',
#   '1907',
#   'Engineering Library'],
#  ['Optimized asymmetric application',
#   'Ricky Edwards',
#   '1929',
#   'Data Science Library'],
#  ['Re-engineered incremental access',
#   'Justin Hawkins',
#   '1905',
#   'Main Library'],
#  ['Proactive optimal protocol', 'Jeffrey Sanchez DDS', '1981', 'Main Library'],
#  ['Ergonomic transitional adapter', 'Wanda West', '1950', 'Main Library'],
#  ['Face-to-face secondary Graphical User Interface',
#   'Ariel Bernard',
#   '1959',
#   'Engineering Library'],
#  ['Triple-buffered multimedia throughput',
#   'David Valencia',
#   '1971',
#   'Main Library'],
#  ['User-centric explicit emulation',
#   'Stephanie Price',
#   '1994',
#   'Engineering Library'],
#  ['Configurable 6thgeneration open architecture',
#   'Krystal Bender',
#   '1967',
#   'Main Library'],
#  ['Implemented optimal website',
#   'Jeffrey Burns',
#   '2016',
#   'Engineering Library'],
#  ['Customer-focused transitional migration',
#   'Lynn Solis',
#   '1990',
#   'Main Library'],
#  ['Persistent contextually-based contingency',
#   'Jason Rodriguez',
#   '1937',
#   'Engineering Library'],
#  ['Exclusive 4thgeneration conglomeration',
#   'Heather Nolan',
#   '2019',
#   'Data Science Library'],
#  ['Visionary web-enabled adapter', 'Michael Fleming', '2010', 'Main Library'],
#  ['Grass-roots bandwidth-monitored model',
#   'Robert Sullivan',
#   '1970',
#   'Engineering Library'],
#  ['Reduced bottom-line system engine', 'Jacob Cooper', '1983', 'Main Library'],
#  ['Multi-channeled multi-state standardization',
#   'David Rose',
#   '1998',
#   'Data Science Library'],
#  ['Secured object-oriented toolset',
#   'Jessica Roth',
#   '2016',
#   'Engineering Library'],
#  ['Right-sized regional software', 'Ryan Wood', '2006', 'Main Library'],
#  ['Profit-focused stable Graphic Interface',
#   'Patrick Kline',
#   '1961',
#   'Engineering Library'],
#  ['Diverse logistical adapter',
#   'Harold Moreno',
#   '1970',
#   'Engineering Library'],
#  ['Switchable discrete complexity',
#   'Bernard Byrd',
#   '1978',
#   'Data Science Library'],
#  ['Function-based hybrid conglomeration',
#   'Erik Mathews',
#   '1918',
#   'Data Science Library'],
#  ['Open-source exuding open architecture',
#   'Brian Pittman',
#   '1948',
#   'Engineering Library'],
#  ['Up-sized cohesive hardware',
#   'Margaret Swanson',
#   '1992',
#   'Data Science Library'],
#  ['Total bifurcated capacity', 'David Nguyen', '2022', 'Main Library'],
#  ['Stand-alone motivating paradigm',
#   'David Rivera',
#   '1955',
#   'Engineering Library'],
#  ['Re-contextualized asynchronous extranet',
#   'Aaron Williams',
#   '1930',
#   'Engineering Library'],
#  ['User-friendly homogeneous customer loyalty',
#   'Roger Thompson',
#   '1902',
#   'Main Library'],
#  ['Cloned intermediate knowledgebase',
#   'Linda Moreno',
#   '2002',
#   'Data Science Library'],
#  ['Organized zero-defect alliance',
#   'Kristin Faulkner',
#   '2021',
#   'Engineering Library'],
#  ['Realigned eco-centric emulation',
#   'Emily Chavez',
#   '2009',
#   'Engineering Library'],
#  ['User-friendly motivating middleware',
#   'Erika Obrien',
#   '1964',
#   'Data Science Library'],
#  ['Secured 5thgeneration protocol',
#   'Jeffrey Johnson',
#   '1948',
#   'Data Science Library'],
#  ['Distributed human-resource policy',
#   'Jessica Smith',
#   '1984',
#   'Engineering Library'],
#  ['User-friendly interactive hierarchy',
#   'James Patterson',
#   '1949',
#   'Data Science Library'],
#  ['Public-key user-facing artificial intelligence',
#   'Peter Cruz',
#   '1945',
#   'Engineering Library'],
#  ['Inverse foreground capacity', 'John Brown', '1951', 'Engineering Library'],
#  ['Configurable contextually-based implementation',
#   'Max Lucas',
#   '1942',
#   'Engineering Library'],
#  ['Public-key maximized infrastructure',
#   'Christopher Bradley',
#   '1969',
#   'Engineering Library'],
#  ['Robust national emulation', 'Sonya Ayala', '1909', 'Main Library'],
#  ['Diverse actuating matrices', 'Erin Flynn', '1907', 'Data Science Library'],
#  ['Adaptive human-resource open architecture',
#   'John Beck',
#   '1957',
#   'Main Library'],
#  ['Monitored scalable secured line',
#   'Alexa Reed',
#   '1985',
#   'Data Science Library'],
#  ['Pre-emptive executive superstructure',
#   'Michael Mcpherson',
#   '1906',
#   'Main Library'],
#  ['Right-sized intermediate collaboration',
#   'Gina Dean',
#   '1987',
#   'Data Science Library'],
#  ['Re-engineered bandwidth-monitored ability',
#   'William Williams',
#   '2004',
#   'Engineering Library'],
#  ['Innovative systematic data-warehouse',
#   'Kyle Knight',
#   '1933',
#   'Data Science Library'],
#  ['Right-sized heuristic workforce', 'Kylie Cochran', '1921', 'Main Library'],
#  ['Compatible bifurcated approach',
#   'Troy Ferguson',
#   '1936',
#   'Data Science Library'],
#  ['Total zero-defect array', 'Melissa Hayes', '1929', 'Engineering Library'],
#  ['User-friendly well-modulated architecture',
#   'Hannah Mcpherson',
#   '1943',
#   'Main Library'],
#  ['Enhanced 24hour concept', 'James Hudson', '2003', 'Main Library'],
#  ['Profound 24hour support', 'Terry Williams', '1963', 'Data Science Library'],
#  ['Adaptive reciprocal initiative',
#   'Elizabeth Huang',
#   '1936',
#   'Data Science Library'],
#  ['Innovative actuating Local Area Network',
#   'Peter Peters',
#   '1940',
#   'Main Library'],
#  ['Organic disintermediate archive',
#   'Vanessa Dixon',
#   '2001',
#   'Data Science Library'],
#  ['User-centric transitional architecture',
#   'Timothy Green',
#   '1950',
#   'Data Science Library'],
#  ['Balanced coherent circuit', 'Brian Brooks', '2003', 'Main Library'],
#  ['Reverse-engineered scalable budgetary management',
#   'Rachel Garcia',
#   '1983',
#   'Main Library'],
#  ['Right-sized demand-driven matrix',
#   'William Robinson',
#   '1993',
#   'Data Science Library'],
#  ['Operative systematic ability', 'Diane Sanford', '1998', 'Main Library'],
#  ['Customer-focused grid-enabled methodology',
#   'Sean Wall',
#   '2019',
#   'Data Science Library'],
#  ['Face-to-face multimedia analyzer', 'Tara Vargas', '1968', 'Main Library'],
#  ['Programmable global moderator',
#   'Tammy Grant',
#   '1923',
#   'Data Science Library'],
#  ['Multi-layered 4thgeneration synergy',
#   'Daniel Chavez',
#   '1967',
#   'Engineering Library'],
#  ['Programmable zero administration portal',
#   'Christopher Robinson',
#   '2001',
#   'Engineering Library'],
#  ['Streamlined national matrices',
#   'Charles Moore PhD',
#   '1909',
#   'Data Science Library'],
#  ['Polarized system-worthy solution',
#   'Jason Davis',
#   '1998',
#   'Data Science Library'],
#  ['User-friendly executive website',
#   'Amber Warren',
#   '2000',
#   'Engineering Library'],
#  ['Balanced local architecture',
#   'Christopher Hurley',
#   '1904',
#   'Data Science Library'],
#  ['User-friendly radical neural-net',
#   'Cheyenne Carr',
#   '1981',
#   'Engineering Library'],
#  ['Advanced scalable synergy', 'Cody Reid', '1982', 'Data Science Library'],
#  ['Enterprise-wide executive artificial intelligence',
#   'Laura Holt',
#   '1976',
#   'Engineering Library'],
#  ['Sharable web-enabled utilization', 'Tamara Wilson', '2007', 'Main Library'],
#  ['Devolved methodical definition',
#   'Virginia Hawkins',
#   '1933',
#   'Engineering Library'],
#  ['Stand-alone uniform function', 'Danny Holden', '1961', 'Main Library'],
#  ['Organized executive database',
#   'Courtney Davis',
#   '2011',
#   'Engineering Library'],
#  ['Inverse client-server moratorium',
#   'Jacqueline Lopez',
#   '2002',
#   'Data Science Library'],
#  ['Automated secondary concept', 'Jennifer Holland', '1932', 'Main Library'],
#  ['Inverse value-added standardization', 'Sarah Bush', '1935', 'Main Library'],
#  ['Pre-emptive system-worthy functionalities',
#   'Kaitlin Rosales',
#   '1912',
#   'Main Library'],
#  ['Enhanced fresh-thinking portal',
#   'Tracy Smith',
#   '1977',
#   'Engineering Library'],
#  ['Phased explicit application',
#   'Jennifer Reyes',
#   '1960',
#   'Data Science Library'],
#  ['Multi-channeled needs-based circuit',
#   'Patricia Guzman',
#   '2007',
#   'Data Science Library'],
#  ['Advanced encompassing budgetary management',
#   'Carla Adams',
#   '1934',
#   'Data Science Library'],
#  ['Profound clear-thinking hardware',
#   'Deanna Garcia',
#   '1933',
#   'Data Science Library'],
#  ['Universal mobile complexity', 'Timothy Lin', '1988', 'Engineering Library'],
#  ['Progressive responsive hub',
#   'Rebecca Torres',
#   '1972',
#   'Data Science Library'],
#  ['Seamless intangible help-desk',
#   'Kevin Bowers',
#   '1910',
#   'Engineering Library'],
#  ['Compatible dynamic help-desk',
#   'Craig Garner',
#   '1924',
#   'Engineering Library'],
#  ['Streamlined real-time policy',
#   'Erin Gomez',
#   '1914',
#   'Data Science Library'],
#  ['Sharable 24hour array', 'Jacob Kennedy', '1964', 'Engineering Library'],
#  ['Re-contextualized optimal encoding',
#   'Joseph Johnson',
#   '1903',
#   'Engineering Library'],
#  ['Persevering leadingedge hardware',
#   'Heather Parks',
#   '1993',
#   'Data Science Library'],
#  ['Public-key stable Graphical User Interface',
#   'Jeffery Christian',
#   '2022',
#   'Engineering Library'],
#  ['Advanced empowering help-desk', 'Kelly Alexander', '1925', 'Main Library'],
#  ['Reverse-engineered context-sensitive superstructure',
#   'Peter Silva',
#   '2003',
#   'Engineering Library'],
#  ['Polarized 24/7 encoding', 'Misty Cuevas', '1913', 'Main Library'],
#  ['Synergistic 24/7 Internet solution',
#   'Manuel Hawkins',
#   '1966',
#   'Main Library'],
#  ['Customer-focused zero administration framework',
#   'Kathryn Martin',
#   '1907',
#   'Main Library'],
#  ['Ameliorated hybrid archive', 'Brian Weber', '1934', 'Main Library'],
#  ['Cloned analyzing groupware',
#   'Amanda Franklin',
#   '1927',
#   'Data Science Library'],
#  ['Profit-focused even-keeled database',
#   'Colleen Myers',
#   '1990',
#   'Main Library'],
#  ['Profit-focused disintermediate capacity',
#   'Michelle Mahoney',
#   '1907',
#   'Main Library'],
#  ['Upgradable zero-defect capacity',
#   'Katrina Mejia',
#   '1984',
#   'Engineering Library'],
#  ['De-engineered regional strategy', 'Michael Martin', '2003', 'Main Library'],
#  ['Sharable dynamic definition', 'Debra Martinez', '1900', 'Main Library'],
#  ['Team-oriented real-time success',
#   'Heather Huffman',
#   '2009',
#   'Engineering Library'],
#  ['Cross-platform transitional instruction set',
#   'Lauren Mccarthy',
#   '1970',
#   'Data Science Library'],
#  ['Programmable real-time service-desk',
#   'Patrick Martinez',
#   '1943',
#   'Main Library'],
#  ['Decentralized bandwidth-monitored capability',
#   'Joshua Price',
#   '1939',
#   'Main Library'],
#  ['Intuitive well-modulated toolset',
#   'Michael Fisher',
#   '1944',
#   'Main Library'],
#  ['User-centric interactive circuit',
#   'Alicia Stephens',
#   '1991',
#   'Engineering Library'],
#  ['Synergized methodical analyzer',
#   'Cody Parks',
#   '2008',
#   'Data Science Library'],
#  ['Enhanced reciprocal website',
#   'Heidi Ellison',
#   '1969',
#   'Engineering Library'],
#  ['Cross-group multimedia core', 'Lisa Weiss', '1903', 'Main Library'],
#  ['Focused zero-defect task-force', 'James Frazier', '1979', 'Main Library'],
#  ['Digitized secondary hub',
#   'Tanner Montgomery',
#   '2009',
#   'Engineering Library'],
#  ['Up-sized interactive matrix',
#   'Luis Ramirez',
#   '1997',
#   'Engineering Library'],
#  ['Future-proofed 5thgeneration artificial intelligence',
#   'John Kelly',
#   '1935',
#   'Main Library'],
#  ['Intuitive user-facing strategy',
#   'Elaine Hawkins',
#   '1995',
#   'Engineering Library'],
#  ['Profound secondary secured line',
#   'Gregory Douglas',
#   '1949',
#   'Main Library'],
#  ['Streamlined system-worthy utilization',
#   'Ryan Sullivan',
#   '1969',
#   'Main Library'],
#  ['Ameliorated multi-state capacity',
#   'Mario Hayes',
#   '1934',
#   'Engineering Library'],
#  ['Seamless scalable interface', 'Jennifer Espinoza', '1910', 'Main Library'],
#  ['Optional discrete matrix', 'Amanda Rangel', '1917', 'Main Library'],
#  ['Persevering dedicated Graphical User Interface',
#   'Nicole Ramos',
#   '1973',
#   'Main Library'],
#  ['Streamlined object-oriented emulation',
#   'Jesse Spence',
#   '2014',
#   'Engineering Library'],
#  ['Networked dynamic open system', 'Tristan Greene', '2016', 'Main Library'],
#  ['Managed upward-trending help-desk',
#   'Sandra Baker',
#   '1958',
#   'Data Science Library'],
#  ['Grass-roots mobile focus group',
#   'Matthew Carter',
#   '1944',
#   'Engineering Library'],
#  ['Profit-focused fresh-thinking functionalities',
#   'Jason Mejia',
#   '1970',
#   'Data Science Library'],
#  ['Reduced neutral circuit', 'Larry Bailey', '1904', 'Engineering Library'],
#  ['Phased hybrid toolset', 'Michael Huber', '2007', 'Engineering Library'],
#  ['Visionary regional secured line',
#   'Kimberly Campbell',
#   '2008',
#   'Main Library'],
#  ['Versatile needs-based task-force',
#   'Shannon Lopez',
#   '2021',
#   'Engineering Library'],
#  ['User-centric upward-trending groupware',
#   'Jonathan Marshall',
#   '2002',
#   'Data Science Library'],
#  ['Reverse-engineered scalable hardware',
#   'Amanda Martinez',
#   '1965',
#   'Main Library'],
#  ['Up-sized clear-thinking model',
#   'Ashley Fox',
#   '1923',
#   'Data Science Library'],
#  ['Polarized encompassing middleware',
#   'Brian Williams',
#   '1921',
#   'Main Library'],
#  ['Business-focused mobile hardware', 'Shawn Acosta', '1933', 'Main Library'],
#  ['Up-sized background contingency',
#   'Michael Valencia',
#   '1996',
#   'Data Science Library'],
#  ['Implemented dynamic contingency',
#   'Nathaniel Anderson',
#   '1967',
#   'Engineering Library'],
#  ['Reduced regional product',
#   'Joann Williams',
#   '1983',
#   'Data Science Library'],
#  ['De-engineered high-level architecture',
#   'Larry Sandoval',
#   '2004',
#   'Data Science Library'],
#  ['Visionary next generation function',
#   'Jonathan Novak',
#   '1997',
#   'Data Science Library'],
#  ['Networked full-range contingency',
#   'Melissa Roberts',
#   '1900',
#   'Data Science Library'],
#  ['Stand-alone bifurcated interface', 'John Simmons', '2002', 'Main Library'],
#  ['Decentralized human-resource solution',
#   'Rachael Sanchez',
#   '2001',
#   'Data Science Library'],
#  ['Up-sized holistic synergy', 'John Adams', '2001', 'Data Science Library'],
#  ['Adaptive executive product', 'Charles Smith', '2005', 'Main Library'],
#  ['Exclusive clear-thinking superstructure',
#   'Suzanne Nelson',
#   '1984',
#   'Engineering Library'],
#  ['Synergized clear-thinking process improvement',
#   'Terry Serrano',
#   '1938',
#   'Main Library'],
#  ['Synchronized 3rdgeneration info-mediaries',
#   'Denise Gould',
#   '2010',
#   'Data Science Library'],
#  ['Persevering scalable matrices',
#   'Kristina Flores',
#   '2014',
#   'Engineering Library'],
#  ['Networked cohesive service-desk', 'John Lewis', '2000', 'Main Library'],
#  ['Operative foreground conglomeration',
#   'Kevin Bell',
#   '1915',
#   'Engineering Library'],
#  ['Front-line local functionalities',
#   'Bradley King PhD',
#   '2004',
#   'Data Science Library'],
#  ['Stand-alone intermediate function',
#   'James Williams',
#   '1939',
#   'Engineering Library'],
#  ['Quality-focused intermediate initiative',
#   'David Reynolds',
#   '1968',
#   'Main Library'],
#  ['Enterprise-wide non-volatile workforce',
#   'Christopher Garrison',
#   '2003',
#   'Main Library'],
#  ['Reverse-engineered zero tolerance synergy',
#   'Victoria Hubbard',
#   '1933',
#   'Engineering Library'],
#  ['Open-source needs-based monitoring',
#   'Debra Torres',
#   '2018',
#   'Data Science Library'],
#  ['Mandatory tangible hierarchy',
#   'Christian Murillo',
#   '1948',
#   'Engineering Library'],
#  ['Ergonomic user-facing focus group',
#   'Catherine Holmes',
#   '2020',
#   'Main Library'],
#  ['Persistent bi-directional matrix',
#   'Lori French',
#   '1957',
#   'Data Science Library'],
#  ['Team-oriented full-range initiative',
#   'Michelle Figueroa',
#   '1975',
#   'Engineering Library'],
#  ['Realigned grid-enabled encryption',
#   'Melanie Fleming',
#   '1956',
#   'Engineering Library'],
#  ['Polarized transitional service-desk',
#   'Terry Wheeler',
#   '1971',
#   'Main Library'],
#  ['Expanded 24hour methodology',
#   'Diana Flores',
#   '1946',
#   'Data Science Library'],
#  ['Up-sized multi-tasking hardware',
#   'William Mercer',
#   '1978',
#   'Data Science Library'],
#  ['Centralized 4thgeneration focus group',
#   'Keith Fisher',
#   '1921',
#   'Data Science Library'],
#  ['Streamlined client-driven projection',
#   'Nichole Medina',
#   '1976',
#   'Data Science Library'],
#  ['Implemented heuristic analyzer',
#   'Kelly Duran',
#   '1905',
#   'Engineering Library'],
#  ['Function-based zero-defect hierarchy',
#   'Mark Short',
#   '1955',
#   'Data Science Library'],
#  ['Cloned global methodology', 'Renee Brown', '1936', 'Main Library'],
#  ['Future-proofed bi-directional process improvement',
#   'Lisa Werner',
#   '2004',
#   'Data Science Library'],
#  ['Configurable well-modulated hub',
#   'Lori White',
#   '1977',
#   'Engineering Library'],
#  ['Assimilated static middleware',
#   'Anthony Young',
#   '1963',
#   'Data Science Library'],
#  ['Reduced systemic extranet', 'Matthew Combs', '1960', 'Engineering Library'],
#  ['Seamless user-facing algorithm',
#   'Derek Cunningham',
#   '2020',
#   'Engineering Library'],
#  ['Assimilated web-enabled benchmark',
#   'Mary Mccoy',
#   '1938',
#   'Engineering Library'],
#  ['Focused homogeneous encoding',
#   'Mr. Carl Eaton MD',
#   '1983',
#   'Data Science Library'],
#  ['Profit-focused transitional policy',
#   'Melissa Carroll',
#   '1953',
#   'Engineering Library'],
#  ['De-engineered bottom-line application',
#   'Brittney Clark',
#   '1903',
#   'Data Science Library'],
#  ['Synchronized systemic installation',
#   'Jodi Davenport',
#   '1946',
#   'Main Library'],
#  ['Front-line optimizing middleware',
#   'Mr. Jared Nguyen',
#   '1963',
#   'Data Science Library'],
#  ['Front-line grid-enabled workforce',
#   'Norma Hughes',
#   '1900',
#   'Engineering Library'],
#  ['Devolved holistic interface', 'Laura Lawrence', '1914', 'Main Library'],
#  ['Pre-emptive heuristic adapter',
#   'Pamela Smith',
#   '1957',
#   'Data Science Library'],
#  ['Vision-oriented zero tolerance middleware',
#   'Jacob Sanders',
#   '1967',
#   'Data Science Library'],
#  ['Virtual systemic intranet', 'Christine Kelley', '1949', 'Main Library'],
#  ['Versatile heuristic contingency',
#   'Ryan Smith',
#   '1928',
#   'Data Science Library'],
#  ['Ameliorated intangible approach',
#   'Ashley Berger',
#   '2022',
#   'Data Science Library'],
#  ['Re-engineered full-range capacity', 'Ethan Clark', '1993', 'Main Library'],
#  ['Configurable exuding Graphic Interface',
#   'Corey Cervantes',
#   '1990',
#   'Engineering Library'],
#  ['Open-source responsive workforce',
#   'Kenneth Lewis',
#   '2011',
#   'Engineering Library'],
#  ['Re-contextualized analyzing hierarchy',
#   'Jessica Moreno',
#   '1996',
#   'Data Science Library'],
#  ['Virtual analyzing instruction set',
#   'Stephen Lee',
#   '2014',
#   'Engineering Library'],
#  ['Total dynamic software', 'Jeffrey Ochoa', '1978', 'Engineering Library'],
#  ['Centralized 3rdgeneration budgetary management',
#   'Christopher Fitzgerald',
#   '1995',
#   'Main Library'],
#  ['Inverse didactic flexibility',
#   'Kari Peterson',
#   '1979',
#   'Data Science Library'],
#  ['Exclusive multi-state knowledge user',
#   'Jill Banks',
#   '1943',
#   'Data Science Library'],
#  ['Centralized motivating encoding',
#   'Tyler James',
#   '2006',
#   'Data Science Library'],
#  ['Fully-configurable multi-state hierarchy',
#   'Mariah Townsend',
#   '1958',
#   'Engineering Library'],
#  ['Intuitive interactive orchestration',
#   'Christine Jackson',
#   '1980',
#   'Data Science Library'],
#  ['Intuitive mobile utilization',
#   'Alison Jones',
#   '1917',
#   'Engineering Library'],
#  ['Operative solution-oriented approach',
#   'Andrea Smith',
#   '1920',
#   'Data Science Library'],
#  ['Centralized coherent structure',
#   'Allison Flores',
#   '1930',
#   'Data Science Library'],
#  ['Automated systemic emulation',
#   'Heather Anderson',
#   '1991',
#   'Data Science Library'],
#  ['De-engineered homogeneous model', 'Donna Rivera', '1970', 'Main Library'],
#  ['Decentralized zero administration contingency',
#   'Michael Singh',
#   '1911',
#   'Data Science Library'],
#  ['Distributed responsive ability',
#   'Jeremiah Ayala',
#   '1947',
#   'Engineering Library'],
#  ['Robust cohesive attitude',
#   'Roger Robertson',
#   '1947',
#   'Engineering Library'],
#  ['Seamless tertiary initiative', 'John Le', '1906', 'Engineering Library'],
#  ['Decentralized 24/7 projection', 'Logan Cunningham', '1946', 'Main Library'],
#  ['User-friendly solution-oriented info-mediaries',
#   'Dr. Michael Stewart',
#   '1949',
#   'Main Library'],
#  ['Robust object-oriented Local Area Network',
#   'Brandon Oconnor',
#   '2007',
#   'Main Library'],
#  ['Public-key cohesive Internet solution',
#   'Mariah Bates',
#   '1937',
#   'Engineering Library'],
#  ['Open-source demand-driven open system',
#   'James Ochoa DVM',
#   '1924',
#   'Main Library'],
#  ['User-centric object-oriented forecast',
#   'Tonya Saunders',
#   '1996',
#   'Main Library'],
#  ['Visionary eco-centric algorithm',
#   'Carol Powell',
#   '1945',
#   'Data Science Library'],
#  ['Managed dynamic encryption', 'Scott Wilson', '1970', 'Main Library'],
#  ['Multi-channeled national synergy',
#   'Tammy Ashley',
#   '1930',
#   'Engineering Library'],
#  ['Expanded hybrid customer loyalty',
#   'Jimmy Mccarthy',
#   '1979',
#   'Main Library'],
#  ['Reverse-engineered incremental capacity',
#   'John Walker',
#   '1910',
#   'Data Science Library'],
#  ['Monitored optimal artificial intelligence',
#   'Dawn Russell',
#   '2022',
#   'Main Library'],
#  ['Switchable systematic capability',
#   'Tanya Dickson',
#   '1936',
#   'Data Science Library'],
#  ['Profit-focused logistical matrix', 'Kelly Fowler', '1925', 'Main Library'],
#  ['Optimized motivating open system',
#   'Patrick Steele',
#   '1956',
#   'Main Library'],
#  ['Universal real-time focus group',
#   'Mrs. Kelly Reynolds',
#   '1911',
#   'Main Library'],
#  ['Reverse-engineered high-level Local Area Network',
#   'Michael Sloan',
#   '2002',
#   'Data Science Library'],
#  ['Profound full-range time-frame',
#   'George Burnett',
#   '1910',
#   'Engineering Library'],
#  ['Customizable client-driven flexibility',
#   'Stephanie Phillips',
#   '1953',
#   'Main Library'],
#  ['Multi-layered bi-directional ability',
#   'Lorraine Washington',
#   '1976',
#   'Main Library'],
#  ['Front-line context-sensitive access',
#   'Margaret Mcdonald',
#   '1976',
#   'Main Library'],
#  ['Robust foreground access',
#   'Allison Rowland',
#   '1919',
#   'Data Science Library'],
#  ['Re-engineered neutral hardware', 'Leslie Rhodes', '1915', 'Main Library'],
#  ['Universal real-time model',
#   'Claudia Hoffman',
#   '1952',
#   'Data Science Library'],
#  ['Sharable real-time matrices',
#   'Wendy Frederick',
#   '1934',
#   'Data Science Library'],
#  ['Triple-buffered 5thgeneration time-frame',
#   'Kirsten Diaz',
#   '1997',
#   'Data Science Library'],
#  ['Balanced non-volatile Local Area Network',
#   'William Ryan',
#   '1904',
#   'Engineering Library'],
#  ['Cross-group local functionalities',
#   'Matthew Chen',
#   '1942',
#   'Data Science Library'],
#  ['Advanced neutral superstructure',
#   'Ryan Reynolds',
#   '1997',
#   'Engineering Library'],
#  ['Organized uniform database',
#   'Anthony Moody',
#   '1981',
#   'Data Science Library'],
#  ['Integrated global data-warehouse', 'Robert Gray', '1953', 'Main Library'],
#  ['Reverse-engineered intangible superstructure',
#   'Marcia Blake',
#   '2019',
#   'Data Science Library'],
#  ['Secured fresh-thinking extranet',
#   'Janice Mitchell',
#   '2017',
#   'Main Library'],
#  ['Customer-focused context-sensitive encoding',
#   'Amanda Herman',
#   '1929',
#   'Engineering Library'],
#  ['Adaptive attitude-oriented open system',
#   'Ryan Garza',
#   '2001',
#   'Main Library'],
#  ['Stand-alone motivating encryption',
#   'Christopher Freeman',
#   '1972',
#   'Main Library'],
#  ['Organized actuating productivity',
#   'Michael Blake',
#   '1935',
#   'Engineering Library'],
#  ['Streamlined modular encoding',
#   'Timothy Rios',
#   '1947',
#   'Data Science Library'],
#  ['Realigned maximized focus group',
#   'Robert Ramirez',
#   '2008',
#   'Engineering Library'],
#  ['User-friendly national instruction set',
#   'Adam Vasquez',
#   '2013',
#   'Main Library'],
#  ['Managed user-facing projection',
#   'Adam Gallegos',
#   '1933',
#   'Engineering Library'],
#  ['Persistent content-based throughput',
#   'Kristen Pennington',
#   '1916',
#   'Engineering Library'],
#  ['Re-engineered 4thgeneration encryption',
#   'James Rodriguez',
#   '1952',
#   'Main Library'],
#  ['Front-line intermediate protocol',
#   'Amy Powell',
#   '1964',
#   'Data Science Library'],
#  ['Extended executive process improvement',
#   'Brett Carson',
#   '1911',
#   'Engineering Library'],
#  ['Customizable transitional ability', 'Aaron Chase', '1943', 'Main Library'],
#  ['Reduced cohesive alliance', 'Darren King', '1986', 'Engineering Library'],
#  ['Innovative tangible Local Area Network',
#   'Nicole Jones',
#   '2006',
#   'Data Science Library']]

# %%
# library별 책 분류하기

# 도서관 관리자 생성
manager = LibraryManager()

# 도서관 생성
library1 = Library("Main Library")
library2 = Library("Data Science Library")
library3 = Library("Engineering Library")

manager.add_library(library1)
manager.add_library(library2)
manager.add_library(library3)

for i in range(len(books)): # 책 배치하는 것도 구멍 뚫어버릴거야
    books[i][2] = int(books[i][2])
    book = Book(books[i][0], books[i][1], books[i][2])
    if books[i][3] == "Main Library" :
        library1.add_book(book, manager)
    elif books[i][3] == "Data Science Library" :
        library2.add_book(book, manager)
    else :
        library3.add_book(book, manager)

# %%
# 도서 정렬 (삽입 정렬) # 삽입 정렬 말고 다른 정렬을 사용할까?
library1.sort_books_title()
library2.sort_books_title()
library3.sort_books_title()

# %% [markdown]
# ## Test case

# %%
library1.show_books()
# Out:
# Adaptive attitude-oriented open system Ryan Garza 2001
# Adaptive executive product Charles Smith 2005
# Adaptive human-resource open architecture John Beck 1957
# Advanced empowering help-desk Kelly Alexander 1925
# Ameliorated hybrid archive Brian Weber 1934
# Assimilated 3rdgeneration throughput Laura Martinez 1920
# Automated secondary concept Jennifer Holland 1932
# Balanced coherent circuit Brian Brooks 2003
# Business-focused mobile hardware Shawn Acosta 1933
# Centralized 3rdgeneration budgetary management Christopher Fitzgerald 1995
# Cloned global methodology Renee Brown 1936
# Configurable 6thgeneration open architecture Krystal Bender 1967
# Cross-group multimedia core Lisa Weiss 1903
# Customer-focused transitional migration Lynn Solis 1990
# Customer-focused zero administration framework Kathryn Martin 1907
# Customizable client-driven flexibility Stephanie Phillips 1953
# Customizable transitional ability Aaron Chase 1943
# De-engineered homogeneous model Donna Rivera 1970
# De-engineered regional strategy Michael Martin 2003
# Decentralized 24/7 projection Logan Cunningham 1946
# Decentralized bandwidth-monitored capability Joshua Price 1939
# Devolved holistic interface Laura Lawrence 1914
# Enhanced 24hour concept James Hudson 2003
# Enterprise-wide non-volatile workforce Christopher Garrison 2003
# Ergonomic transitional adapter Wanda West 1950
# Ergonomic user-facing focus group Catherine Holmes 2020
# Expanded hybrid customer loyalty Jimmy Mccarthy 1979
# Face-to-face multimedia analyzer Tara Vargas 1968
# Focused zero-defect task-force James Frazier 1979
# Front-line context-sensitive access Margaret Mcdonald 1976
# Future-proofed 5thgeneration artificial intelligence John Kelly 1935
# Future-proofed empowering frame Sean Nixon 1979
# Innovative actuating Local Area Network Peter Peters 1940
# Integrated global data-warehouse Robert Gray 1953
# Intuitive well-modulated toolset Michael Fisher 1944
# Inverse value-added standardization Sarah Bush 1935
# Managed dynamic encryption Scott Wilson 1970
# Mandatory zero administration customer loyalty Kayla Walker 1919
# Monitored optimal artificial intelligence Dawn Russell 2022
# Multi-layered bi-directional ability Lorraine Washington 1976
# Multi-layered optimizing workforce David Hudson 1975
# Networked 5thgeneration firmware Pamela White 1946
# Networked cohesive service-desk John Lewis 2000
# Networked dynamic open system Tristan Greene 2016
# Object-based incremental projection Mike Rodriguez 1924
# Open-architected transitional model Nicole Bailey 1933
# Open-source demand-driven open system James Ochoa DVM 1924
# Operative systematic ability Diane Sanford 1998
# Optimized motivating open system Patrick Steele 1956
# Optional discrete matrix Amanda Rangel 1917
# Persevering dedicated Graphical User Interface Nicole Ramos 1973
# Polarized 24/7 encoding Misty Cuevas 1913
# Polarized encompassing middleware Brian Williams 1921
# Polarized transitional service-desk Terry Wheeler 1971
# Pre-emptive executive superstructure Michael Mcpherson 1906
# Pre-emptive system-worthy functionalities Kaitlin Rosales 1912
# Proactive optimal protocol Jeffrey Sanchez DDS 1981
# Profit-focused disintermediate capacity Michelle Mahoney 1907
# Profit-focused even-keeled database Colleen Myers 1990
# Profit-focused logistical matrix Kelly Fowler 1925
# Profound secondary secured line Gregory Douglas 1949
# Programmable real-time service-desk Patrick Martinez 1943
# Quality-focused intermediate initiative David Reynolds 1968
# Re-engineered 4thgeneration encryption James Rodriguez 1952
# Re-engineered full-range capacity Ethan Clark 1993
# Re-engineered incremental access Justin Hawkins 1905
# Re-engineered neutral hardware Leslie Rhodes 1915
# Reduced bottom-line system engine Jacob Cooper 1983
# Reverse-engineered scalable budgetary management Rachel Garcia 1983
# Reverse-engineered scalable hardware Amanda Martinez 1965
# Right-sized heuristic workforce Kylie Cochran 1921
# Right-sized regional software Ryan Wood 2006
# Robust attitude-oriented circuit Joshua Jones 1948
# Robust national emulation Sonya Ayala 1909
# Robust object-oriented Local Area Network Brandon Oconnor 2007
# Seamless scalable interface Jennifer Espinoza 1910
# Secured fresh-thinking extranet Janice Mitchell 2017
# Sharable dynamic definition Debra Martinez 1900
# Sharable web-enabled utilization Tamara Wilson 2007
# Stand-alone bifurcated interface John Simmons 2002
# Stand-alone motivating encryption Christopher Freeman 1972
# Stand-alone uniform function Danny Holden 1961
# Streamlined system-worthy utilization Ryan Sullivan 1969
# Synchronized systemic installation Jodi Davenport 1946
# Synergistic 24/7 Internet solution Manuel Hawkins 1966
# Synergized clear-thinking process improvement Terry Serrano 1938
# Total bifurcated capacity David Nguyen 2022
# Triple-buffered multimedia throughput David Valencia 1971
# Universal real-time focus group Mrs. Kelly Reynolds 1911
# User-centric object-oriented forecast Tonya Saunders 1996
# User-friendly homogeneous customer loyalty Roger Thompson 1902
# User-friendly national instruction set Adam Vasquez 2013
# User-friendly solution-oriented info-mediaries Dr. Michael Stewart 1949
# User-friendly well-modulated architecture Hannah Mcpherson 1943
# Virtual systemic intranet Christine Kelley 1949
# Vision-oriented systemic architecture Amanda Rose 1912
# Visionary asynchronous capability Nathaniel Gallagher 1903
# Visionary regional secured line Kimberly Campbell 2008
# Visionary systemic website Maria Mcmahon 1916
# Visionary web-enabled adapter Michael Fleming 2010
# Visionary zero tolerance structure Kathleen Sanchez 1999

# %%
library2.show_books()
# Out:
# Adaptive reciprocal initiative Elizabeth Huang 1936
# Advanced encompassing budgetary management Carla Adams 1934
# Advanced scalable synergy Cody Reid 1982
# Ameliorated intangible approach Ashley Berger 2022
# Assimilated static middleware Anthony Young 1963
# Automated systemic emulation Heather Anderson 1991
# Balanced local architecture Christopher Hurley 1904
# Centralized 4thgeneration focus group Keith Fisher 1921
# Centralized coherent structure Allison Flores 1930
# Centralized motivating encoding Tyler James 2006
# Cloned analyzing groupware Amanda Franklin 1927
# Cloned intermediate knowledgebase Linda Moreno 2002
# Compatible bifurcated approach Troy Ferguson 1936
# Cross-group local functionalities Matthew Chen 1942
# Cross-platform transitional instruction set Lauren Mccarthy 1970
# Cross-platform transitional leverage Lisa Hurley 1933
# Customer-focused grid-enabled methodology Sean Wall 2019
# De-engineered bottom-line application Brittney Clark 1903
# De-engineered high-level architecture Larry Sandoval 2004
# Decentralized human-resource solution Rachael Sanchez 2001
# Decentralized zero administration contingency Michael Singh 1911
# Diverse actuating matrices Erin Flynn 1907
# Exclusive 4thgeneration conglomeration Heather Nolan 2019
# Exclusive multi-state knowledge user Jill Banks 1943
# Expanded 24hour methodology Diana Flores 1946
# Extended interactive alliance Cassie Barnes 2010
# Face-to-face 6thgeneration ability Elizabeth Weaver 2016
# Focused homogeneous encoding Mr. Carl Eaton MD 1983
# Front-line intermediate protocol Amy Powell 1964
# Front-line local functionalities Bradley King PhD 2004
# Front-line optimizing middleware Mr. Jared Nguyen 1963
# Fully-configurable upward-trending installation Scott Love 1939
# Function-based hybrid conglomeration Erik Mathews 1918
# Function-based zero-defect hierarchy Mark Short 1955
# Future-proofed bi-directional process improvement Lisa Werner 2004
# Innovative systematic data-warehouse Kyle Knight 1933
# Innovative tangible Local Area Network Nicole Jones 2006
# Intuitive intangible customer loyalty Jason Wells 1986
# Intuitive interactive orchestration Christine Jackson 1980
# Inverse client-server moratorium Jacqueline Lopez 2002
# Inverse didactic flexibility Kari Peterson 1979
# Managed upward-trending help-desk Sandra Baker 1958
# Monitored scalable secured line Alexa Reed 1985
# Multi-channeled multi-state standardization David Rose 1998
# Multi-channeled needs-based circuit Patricia Guzman 2007
# Networked full-range contingency Melissa Roberts 1900
# Open-source needs-based monitoring Debra Torres 2018
# Operative solution-oriented approach Andrea Smith 1920
# Optimized asymmetric application Ricky Edwards 1929
# Organic disintermediate archive Vanessa Dixon 2001
# Organized multi-state throughput Brandon Manning 1919
# Organized uniform database Anthony Moody 1981
# Persevering leadingedge hardware Heather Parks 1993
# Persistent bi-directional matrix Lori French 1957
# Phased explicit application Jennifer Reyes 1960
# Polarized system-worthy solution Jason Davis 1998
# Pre-emptive heuristic adapter Pamela Smith 1957
# Profit-focused fresh-thinking functionalities Jason Mejia 1970
# Profound 24hour support Terry Williams 1963
# Profound clear-thinking hardware Deanna Garcia 1933
# Programmable global moderator Tammy Grant 1923
# Progressive responsive hub Rebecca Torres 1972
# Re-contextualized analyzing hierarchy Jessica Moreno 1996
# Reduced leadingedge hierarchy Amy Johnson 1957
# Reduced regional product Joann Williams 1983
# Reverse-engineered high-level Local Area Network Michael Sloan 2002
# Reverse-engineered incremental capacity John Walker 1910
# Reverse-engineered intangible superstructure Marcia Blake 2019
# Right-sized demand-driven matrix William Robinson 1993
# Right-sized intermediate collaboration Gina Dean 1987
# Robust foreground access Allison Rowland 1919
# Secured 5thgeneration protocol Jeffrey Johnson 1948
# Sharable real-time matrices Wendy Frederick 1934
# Streamlined client-driven projection Nichole Medina 1976
# Streamlined modular encoding Timothy Rios 1947
# Streamlined national matrices Charles Moore PhD 1909
# Streamlined real-time policy Erin Gomez 1914
# Switchable discrete complexity Bernard Byrd 1978
# Switchable systematic capability Tanya Dickson 1936
# Synchronized 3rdgeneration info-mediaries Denise Gould 2010
# Synergized methodical analyzer Cody Parks 2008
# Synergized upward-trending application Tammy Keith 1913
# Triple-buffered 5thgeneration time-frame Kirsten Diaz 1997
# Universal real-time model Claudia Hoffman 1952
# Up-sized background contingency Michael Valencia 1996
# Up-sized clear-thinking model Ashley Fox 1923
# Up-sized cohesive hardware Margaret Swanson 1992
# Up-sized holistic synergy John Adams 2001
# Up-sized multi-tasking hardware William Mercer 1978
# User-centric transitional architecture Timothy Green 1950
# User-centric upward-trending groupware Jonathan Marshall 2002
# User-friendly interactive hierarchy James Patterson 1949
# User-friendly motivating middleware Erika Obrien 1964
# Versatile heuristic contingency Ryan Smith 1928
# Vision-oriented zero tolerance middleware Jacob Sanders 1967
# Visionary eco-centric algorithm Carol Powell 1945
# Visionary next generation function Jonathan Novak 1997

# %%
library3.show_books()
# Out:
# Advanced neutral superstructure Ryan Reynolds 1997
# Ameliorated multi-state capacity Mario Hayes 1934
# Assimilated web-enabled benchmark Mary Mccoy 1938
# Balanced non-volatile Local Area Network William Ryan 1904
# Balanced real-time monitoring Joshua Jones 1907
# Balanced upward-trending database Trevor Bell 1999
# Business-focused even-keeled complexity Laura Rich 1971
# Compatible dynamic help-desk Craig Garner 1924
# Configurable contextually-based implementation Max Lucas 1942
# Configurable exuding Graphic Interface Corey Cervantes 1990
# Configurable well-modulated hub Lori White 1977
# Customer-focused context-sensitive encoding Amanda Herman 1929
# Devolved methodical definition Virginia Hawkins 1933
# Devolved mobile software Matthew Montoya 1975
# Digitized secondary hub Tanner Montgomery 2009
# Distributed even-keeled open architecture Jacob Harrison 1915
# Distributed human-resource policy Jessica Smith 1984
# Distributed responsive ability Jeremiah Ayala 1947
# Diverse logistical adapter Harold Moreno 1970
# Enhanced fresh-thinking portal Tracy Smith 1977
# Enhanced reciprocal website Heidi Ellison 1969
# Enterprise-wide executive artificial intelligence Laura Holt 1976
# Exclusive clear-thinking superstructure Suzanne Nelson 1984
# Expanded even-keeled paradigm Melissa Smith 1992
# Extended executive process improvement Brett Carson 1911
# Face-to-face secondary Graphical User Interface Ariel Bernard 1959
# Focused mobile concept Misty Stephenson 1967
# Front-line grid-enabled workforce Norma Hughes 1900
# Fully-configurable multi-state hierarchy Mariah Townsend 1958
# Grass-roots bandwidth-monitored model Robert Sullivan 1970
# Grass-roots mobile focus group Matthew Carter 1944
# Implemented dynamic contingency Nathaniel Anderson 1967
# Implemented heuristic analyzer Kelly Duran 1905
# Implemented optimal website Jeffrey Burns 2016
# Intuitive composite neural-net Dalton Mercado 1984
# Intuitive mobile utilization Alison Jones 1917
# Intuitive user-facing strategy Elaine Hawkins 1995
# Inverse foreground capacity John Brown 1951
# Managed user-facing projection Adam Gallegos 1933
# Mandatory tangible hierarchy Christian Murillo 1948
# Multi-channeled national synergy Tammy Ashley 1930
# Multi-layered 4thgeneration synergy Daniel Chavez 1967
# Networked actuating model Jamie Hansen 2015
# Open-source bifurcated intranet Nicole Rosario 1956
# Open-source client-driven methodology Nicole Russell 1989
# Open-source exuding open architecture Brian Pittman 1948
# Open-source responsive workforce Kenneth Lewis 2011
# Operative foreground conglomeration Kevin Bell 1915
# Organized actuating productivity Michael Blake 1935
# Organized executive database Courtney Davis 2011
# Organized zero-defect alliance Kristin Faulkner 2021
# Persevering composite complexity Madison Ramos 2000
# Persevering scalable matrices Kristina Flores 2014
# Persistent content-based throughput Kristen Pennington 1916
# Persistent contextually-based contingency Jason Rodriguez 1937
# Phased dedicated application Kayla Mitchell 2004
# Phased hybrid toolset Michael Huber 2007
# Polarized encompassing orchestration Jason Haas 1963
# Profit-focused stable Graphic Interface Patrick Kline 1961
# Profit-focused transitional policy Melissa Carroll 1953
# Profound client-driven archive Jay Greene 1993
# Profound full-range time-frame George Burnett 1910
# Programmable zero administration portal Christopher Robinson 2001
# Public-key cohesive Internet solution Mariah Bates 1937
# Public-key maximized infrastructure Christopher Bradley 1969
# Public-key stable Graphical User Interface Jeffery Christian 2022
# Public-key user-facing artificial intelligence Peter Cruz 1945
# Re-contextualized asynchronous extranet Aaron Williams 1930
# Re-contextualized optimal encoding Joseph Johnson 1903
# Re-engineered bandwidth-monitored ability William Williams 2004
# Realigned eco-centric emulation Emily Chavez 2009
# Realigned grid-enabled encryption Melanie Fleming 1956
# Realigned maximized focus group Robert Ramirez 2008
# Reduced cohesive alliance Darren King 1986
# Reduced neutral circuit Larry Bailey 1904
# Reduced systemic extranet Matthew Combs 1960
# Reverse-engineered context-sensitive superstructure Peter Silva 2003
# Reverse-engineered zero tolerance synergy Victoria Hubbard 1933
# Robust cohesive attitude Roger Robertson 1947
# Seamless intangible help-desk Kevin Bowers 1910
# Seamless tertiary initiative John Le 1906
# Seamless user-facing algorithm Derek Cunningham 2020
# Secured object-oriented toolset Jessica Roth 2016
# Secured responsive open system Hector Santos 1950
# Sharable 24hour array Jacob Kennedy 1964
# Stand-alone intermediate function James Williams 1939
# Stand-alone motivating paradigm David Rivera 1955
# Streamlined object-oriented emulation Jesse Spence 2014
# Team-oriented full-range initiative Michelle Figueroa 1975
# Team-oriented real-time success Heather Huffman 2009
# Total dynamic software Jeffrey Ochoa 1978
# Total zero-defect array Melissa Hayes 1929
# Universal mobile complexity Timothy Lin 1988
# Up-sized interactive matrix Luis Ramirez 1997
# Upgradable zero-defect capacity Katrina Mejia 1984
# User-centric explicit emulation Stephanie Price 1994
# User-centric interactive circuit Alicia Stephens 1991
# User-friendly executive website Amber Warren 2000
# User-friendly radical neural-net Cheyenne Carr 1981
# Versatile needs-based task-force Shannon Lopez 2021
# Virtual 4thgeneration task-force John Gilbert 1932
# Virtual analyzing instruction set Stephen Lee 2014

# %%
selected_library_name = "Main Library"
selected_library = manager.select_library(selected_library_name)

if selected_library:
    query = "custom"
    found_books = selected_library.search_book(query)

    if found_books:
        print(f"{selected_library_name}에서 검색 결과 ({query} 관련 도서):")
        for book in found_books:
            print(f"도서 제목: {book.title}")
            print(f"저자: {book.author}")
            print(f"출판연도: {book.year}")
            print('\n')
    else:
        print(f"{selected_library_name}에서 검색 결과가 없습니다.")
else:
    print(f"{selected_library_name}을 찾을 수 없습니다.")
# Out:
# Main Library에서 검색 결과 (custom 관련 도서):
# 도서 제목: Customer-focused transitional migration
# 저자: Lynn Solis
# 출판연도: 1990
#
#
# 도서 제목: Customer-focused zero administration framework
# 저자: Kathryn Martin
# 출판연도: 1907
#
#
# 도서 제목: Customizable client-driven flexibility
# 저자: Stephanie Phillips
# 출판연도: 1953
#
#
# 도서 제목: Customizable transitional ability
# 저자: Aaron Chase
# 출판연도: 1943
#
#
# 도서 제목: Expanded hybrid customer loyalty
# 저자: Jimmy Mccarthy
# 출판연도: 1979
#
#
# 도서 제목: Mandatory zero administration customer loyalty
# 저자: Kayla Walker
# 출판연도: 1919
#
#
# 도서 제목: User-friendly homogeneous customer loyalty
# 저자: Roger Thompson
# 출판연도: 1902

# %%
selected_library_name = "Engineering Library"
selected_library = manager.select_library(selected_library_name)

if selected_library:
    query = "anda"
    found_books = selected_library.search_book(query)

    if found_books:
        print(f"{selected_library_name}에서 검색 결과 ({query} 관련 도서):")
        for book in found_books:
            print(f"도서 제목: {book.title}")
            print(f"저자: {book.author}")
            print(f"출판연도: {book.year}")
            print('\n')
    else:
        print(f"{selected_library_name}에서 검색 결과가 없습니다.")
else:
    print(f"{selected_library_name}을 찾을 수 없습니다.")
# Out:
# Engineering Library에서 검색 결과 (anda 관련 도서):
# 도서 제목: Customer-focused context-sensitive encoding
# 저자: Amanda Herman
# 출판연도: 1929
#
#
# 도서 제목: Mandatory tangible hierarchy
# 저자: Christian Murillo
# 출판연도: 1948

# %%
selected_library_name = "Data Science Library"
selected_library = manager.select_library(selected_library_name)

if selected_library:
    query = "info"
    found_books = selected_library.search_book(query)

    if found_books:
        print(f"{selected_library_name}에서 검색 결과 ({query} 관련 도서):")
        for book in found_books:
            print(f"도서 제목: {book.title}")
            print(f"저자: {book.author}")
            print(f"출판연도: {book.year}")
            print('\n')
    else:
        print(f"{selected_library_name}에서 검색 결과가 없습니다.")
else:
    print(f"{selected_library_name}을 찾을 수 없습니다.")
# Out:
# Data Science Library에서 검색 결과 (info 관련 도서):
# 도서 제목: Synchronized 3rdgeneration info-mediaries
# 저자: Denise Gould
# 출판연도: 2010

# %%
book_title_to_find = "Profit-focused"
matching_books = manager.find_library_of_book(book_title_to_find)

if matching_books:
    print(f"검색 결과 ({book_title_to_find} 관련 도서):")
    for book_title, library in matching_books.items():
        print(f"'{book_title}' 책은 '{library.name}' 도서관에 있습니다.")
else:
    print(f"'{book_title_to_find}' 관련 도서를 찾을 수 없습니다.")
# Out:
# 검색 결과 (Profit-focused 관련 도서):
# 'Profit-focused stable Graphic Interface' 책은 'Engineering Library' 도서관에 있습니다.
# 'Profit-focused even-keeled database' 책은 'Main Library' 도서관에 있습니다.
# 'Profit-focused disintermediate capacity' 책은 'Main Library' 도서관에 있습니다.
# 'Profit-focused fresh-thinking functionalities' 책은 'Data Science Library' 도서관에 있습니다.
# 'Profit-focused transitional policy' 책은 'Engineering Library' 도서관에 있습니다.
# 'Profit-focused logistical matrix' 책은 'Main Library' 도서관에 있습니다.

# %%
book_title_to_find = "24hour"
matching_books = manager.find_library_of_book(book_title_to_find)

if matching_books:
    print(f"검색 결과 ({book_title_to_find} 관련 도서):")
    for book_title, library in matching_books.items():
        print(f"'{book_title}' 책은 '{library.name}' 도서관에 있습니다.")
else:
    print(f"'{book_title_to_find}' 관련 도서를 찾을 수 없습니다.")
# Out:
# 검색 결과 (24hour 관련 도서):
# 'Enhanced 24hour concept' 책은 'Main Library' 도서관에 있습니다.
# 'Profound 24hour support' 책은 'Data Science Library' 도서관에 있습니다.
# 'Sharable 24hour array' 책은 'Engineering Library' 도서관에 있습니다.
# 'Expanded 24hour methodology' 책은 'Data Science Library' 도서관에 있습니다.

# %%
book_title_to_find = "Networked dynamic"
matching_books = manager.find_library_of_book(book_title_to_find)

if matching_books:
    print(f"검색 결과 ({book_title_to_find} 관련 도서):")
    for book_title, library in matching_books.items():
        print(f"'{book_title}' 책은 '{library.name}' 도서관에 있습니다.")
else:
    print(f"'{book_title_to_find}' 관련 도서를 찾을 수 없습니다.")
# Out:
# 검색 결과 (Networked dynamic 관련 도서):
# 'Networked dynamic open system' 책은 'Main Library' 도서관에 있습니다.
