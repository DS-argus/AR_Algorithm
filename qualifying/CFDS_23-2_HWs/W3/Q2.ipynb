# %% [markdown]
# # Assignment 3

# %% [markdown]
# # Assignment 3.2 가장 넓은 박스 면적 구하기

# %%
def get_size(num: int, box: list) -> int:
    # Initialize stack and max_result
    stack = []
    max_result = 0
    # i = 0

    # while i < num:
    # ############Q2.1 Write your own code############
    #     while stack and box[i] < box[stack[-1]]:
        
    #         h = box[stack[-1]]
    #         w = i - stack[-1]
    #         max_result = max(max_result, h*w) 
    #         stack.pop()
        
    #     stack.append(i)
    #     i += 1
    # ################################################
    # print(stack, max_result)
    # while stack:
    #   ############Q2.2 Write your own code############
    #     h = box[stack[-1]]
    #     w = num - stack[-1]
    #     max_result = max(max_result, h*w)
    #     stack.pop()
    #     print(max_result,h, w)
    #   ################################################

    return max_result

# %%
# Given Example 1
get_size(7, [2,1,4,5,1,3,3])
# Out:
# [1, 4, 5, 6] 8
# 8 3 1
# 8 3 2
# 8 1 3
# 8 1 6
# 8

# %%
# Given Example 2
get_size(10, [3,7,1,9,8,7,4,5,9,10])
# Out:
# [2, 6, 7, 8, 9] 9
# 10 10 1
# 18 9 2
# 18 5 3
# 18 4 4
# 18 1 8
# 18

# %%
# Given Example 3
get_size(0, [])
# Out:
# 0
